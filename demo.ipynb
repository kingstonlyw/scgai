# %%
from google import genai
from pypdf import PdfReader
from pathlib import Path
import json

GEMINI_API_KEY = "AIzaSyALqNYH09t5vVVK07hwb-SppRL7jI2OQI8"
client = genai.Client(api_key=GEMINI_API_KEY)
#user input
user_input = "How is the boston market doing?"
#prompt engineering
specifics = "Only use information that is passed along with the prompt."
response_file = "responses.txt"
final_output = "final_output.json"

# %% [markdown]
# Prompt LLM with information from every pdf and compile in responses.txt file

# %%
#prompt llm with information from every pdf
for pdf in Path(".").glob("*.pdf"):
    print(pdf)
    r = PdfReader(pdf)
    text = "\n".join((p.extract_text() or "") for p in r.pages)
    new_prompt = text+specifics+user_input
    response = client.models.generate_content(model = "gemini-2.5-flash", contents = new_prompt)
    #print(response.text[:100])
    with open(response_file, "a", encoding="utf-8") as f:
        output = str(pdf) + "\n"+response.text+"\n\n"
        f.write(output)

# %% [markdown]
# Prompt LLM with responses.txt

# %%
#prompt llm with all responses and have 
specifics = "You are a market analyst compiling a brief, detailed report. Summarize the text and present common themes, with respect to the following prompt: "
with open("responses.txt", 'r') as f:
    new_prompt = f.read()+specifics+user_input
response = client.models.generate_content(model = "gemini-2.5-flash", contents = new_prompt)
print(response.text)
#write to json or whatever output type needed
with open(final_output, "w", encoding="utf-8") as f:
    json.dump(response.text, f, indent=2)
# Out:
# The Boston real estate market in 2025 presents a mixed and somewhat challenged picture across the sectors for which data is available, showing signs of moderation, increased supply-side pressure in some areas, and a shift towards tenant-favored conditions.
#
# Here's a breakdown by sector:
#
# ### Multifamily Sector (2025 Midyear Outlook)
#
# *   **Moderated Outlook:** Boston's multifamily market is experiencing a **moderated outlook for rent growth**.
# *   **Downgraded Rent Forecast:** The five-year compound annual growth rate (CAGR) for multifamily rent has been **downgraded at midyear**, now projected around **2.4-2.5%**. This forecast is notably **below the national average (Sum of Markets) of 2.8%**.
# *   **Lower Employment Correlation:** The market shows a **lower correlation (around 30-40%)** between annual multifamily rent and employment growth compared to many other major U.S. markets, suggesting its rent performance is less directly tied to job market fluctuations.
#
# ### Industrial Sector (Q3 2025 Dynamics)
#
# *   **Shifting Environment:** The industrial market, while showing **resilience** despite macroeconomic headwinds, is definitively **shifting towards a tenant-favored environment**, with landlords cutting rents and increasing concessions.
# *   **Rising Vacancy:** Total vacancy **grew to 8.3%** in Q3 2025 (up 30 bps QoQ and 100 bps YoY), largely attributed to **speculative warehouses delivering vacant**.
#     *   **Market Bifurcation:** A significant difference exists between property sizes: vacancy in buildings **under 100,000 s.f. was 4.6%**, while properties **over 100,000 s.f. saw 10.2% vacancy**.
#     *   **Outlook:** A decrease in large-block vacancy is anticipated due to rebounding demand.
# *   **Contracting Rents:** Average asking rents have continued to **contract**, dropping to **$15.19 NNN p.s.f.**, a **1.6% fall since the start of the year**.
# *   **Mixed Demand & Leasing:**
#     *   **Negative Net Absorption** for Q3 (-105,015 s.f.), though year-to-date net absorption remains positive (450,918 s.f.).
#     *   Year-to-date total leasing volume is **down 34%** compared to last year.
#     *   Q3 activity was heavily driven by **renewals (59%)**, as tenants delayed relocations.
#     *   **Outlook:** Demand has **rebounded significantly (14% increase QoQ)**, with large tenants refocusing on expansion, which is expected to positively impact large block availability.
# *   **Robust but Slowing Speculative Supply:** The development pipeline is **robust with 6.3 m.s.f. under construction**, with 3.5 m.s.f. being build-to-suit. However, the pipeline for new **spec projects has decreased by 54%** compared to Q3 2023, indicating a slowdown in new speculative construction.
#
# ### Overall Themes
#
# *   **Moderation and Rebalancing:** Both sectors show signs of moderation or rebalancing. Multifamily rent growth is slowing and is below national averages. Industrial is navigating increased vacancy and contracting rents, shifting leverage to tenants.
# *   **Impact of Supply:** In the industrial sector, recent speculative deliveries have contributed significantly to rising vacancy, particularly in larger properties.
# *   **Resilience with Challenges:** Despite headwinds, both markets exhibit underlying resilience. Industrial is facing immediate challenges from oversupply and economic uncertainty, but a rebound in demand and a slowdown in future speculative supply suggest potential stabilization.
# *   **Less Tied to Employment (Multifamily):** Boston's multifamily market appears less sensitive to direct employment growth fluctuations compared to other major metros.
#
# In summary, the Boston market is undergoing a period of adjustment. The multifamily sector expects more modest rent growth, while the industrial market is navigating tenant-friendly conditions, marked by rising vacancy (especially for larger spaces) and contracting rents. However, the industrial market also shows promising signs of a demand rebound and a tapering off of new speculative supply, potentially leading to future stabilization in larger block availabilities.
